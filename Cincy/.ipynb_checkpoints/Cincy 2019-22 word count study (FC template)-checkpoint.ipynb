# %%
# import packages
import pandas as pd
import os
import glob
import random
import numpy as np
import statistics
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import ttest_rel
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import matplotlib.patches as mpatches

import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import statsmodels.formula.api as smf
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# ## Data Prep

# %%
# import word count .csv file from local path
path = r'/Users/spencersu/Desktop/Cincy'
bchmrk = pd.read_csv(os.path.join(path, 'Cincy Benchmark 2019-22.csv')) # 318 rows × 14 columns
wrtlsn = pd.read_csv(os.path.join(path, 'Cincy Writing Lesson 2019-22.csv')) #747 rows × 14 columns

# %%
# check if there is na for word count
bchmrk['Word Count'].isnull().any()
wrtlsn['Word Count'].isnull().any()
# Out:
# True

# %%
# remove column: the first column "Unnamed: 0"
bchmrk = bchmrk.iloc[:,1:14]

## change data type into integer: 'Word Count' column
# drop nan for Word Count column
bchmrk = bchmrk.dropna(subset=['Word Count'])

# replace ',' with ''
bchmrk['Word Count'].replace(',','',regex=True,inplace=True)

# convert data type of word count column into integer
bchmrk['Word Count'] = bchmrk['Word Count'].astype(int)


# wordcnt dataset now has 315 rows × 13 columns
# data retrieved on Mar 23, 2022

# %%
# remove column: the first column "Unnamed: 0"
wrtlsn = wrtlsn.iloc[:,1:14]

## change data type into integer: 'Word Count' column
# drop nan for Word Count column
wrtlsn = wrtlsn.dropna(subset=['Word Count'])

# replace ',' with ''
wrtlsn['Word Count'].replace(',','',regex=True,inplace=True)

# convert data type of word count column into integer
wrtlsn['Word Count'] = wrtlsn['Word Count'].astype(int)

# wordcnt dataset now has 720 rows × 13 columns
# data retrieved on Mar 23, 2022

# %% [markdown]
# ## Data Overview

# %%
## count the unique number of student assignments and students (students has the same number of student assignments for benchmarks)
## also count total writing lessons 

print(bchmrk.groupby(['School Year','Lesson Type','Enrolled Grade'])['Student Assignment ID'].nunique())
print(bchmrk.groupby(['School Year','Lesson Type'])['Student Assignment ID'].nunique())
print(wrtlsn.groupby(['School Year','Enrolled Grade'])['Student Assignment ID', 'Student ID'].nunique())
print(wrtlsn.groupby(['School Year'])['Student Assignment ID','Student ID'].nunique())
# Out:
# School Year  Lesson Type                   Enrolled Grade
# 2019-2020    Benchmark - Baseline Writing  7                  1
#                                            8                  7
#                                            9                 31
#                                            10                46
#                                            11                15
#                                            12                 5
#              Benchmark - End-of-Year       8                  1
#                                            9                  7
#                                            10                 8
#                                            11                 5
#                                            12                 1
#              Benchmark - Mid-Year          7                  1
#                                            8                  5
#                                            9                 26
# ...

# %%
# not removing outliers yet
print(wrtlsn.groupby(['School Year','Enrolled Grade'])['Word Count'].mean())#.to_csv(os.path.join(path, 'Word Count Overview.csv'))
print(bchmrk.groupby(['School Year','Lesson Type','Enrolled Grade'])['Word Count'].mean())
# Out:
# School Year  Enrolled Grade
# 2019-2020    7                 332.000000
#              8                 364.958333
#              9                 333.208333
#              10                223.621212
#              11                178.897436
#              12                193.000000
# 2020-2021    9                  87.333333
#              10                121.863636
#              11                161.050633
#              12                248.363636
#              13                 56.000000
# 2021-2022    7                 212.120000
#              8                 262.428571
#              9                 119.121212
#              10                149.770370
#              11                104.181818
#              12                113.538462
# Name: Word Count, dtype: float64
# School Year  Lesson Type                   Enrolled Grade
# 2019-2020    Benchmark - Baseline Writing  7                 118.000000
# ...

# %%
# create two separate datasets for word count and scores respectively (for all school years), and without rubric categories 

def drop_columns(df_original, groups, y):
    df = df_original.groupby(groups)[y].mean()
    df = pd.DataFrame(df)
    df = df.reset_index()
    return df

group_bchmrk = ['School Year','School Name','Class Name',
                'Lesson Type', 'Class Subject', 'Teacher Name [Sensitive]',
                'Student ID', 'Full Name', 'Enrolled Grade', 'Lesson ID', 'Student Assignment ID']

bchmrk_ws = drop_columns(bchmrk, group_bchmrk, 'Writing Score') # 1779 rows × 12 columns
bchmrk_wc = drop_columns(bchmrk, group_bchmrk, 'Word Count') # 1779 rows × 12 columns

# %%
# remove outliers for word count based on year and lesson type

def remove_outlier(df, column, group, y):
    g = df[df[column]==group]
    z = np.abs(stats.zscore(g[y]))
    g['z'] = z
    # threshold = 3
    g = g[g['z']<3]
    g.drop(['z'],axis=1,inplace=True)
    return g

bchmrk2122_wc = remove_outlier(bchmrk_wc, 'School Year', '2021-2022', 'Word Count') # 1536 rows × 12 columns
bchmrk2122_ws = remove_outlier(bchmrk_ws, 'School Year', '2021-2022', 'Writing Score') #1547 rows × 12 columns

## if we want to know the correlation between ws and wc, merge the two datasets here below

# %%
bchmrk2122_ws
# Out:
#      School Year               School Name                    Class Name  \
# 232    2021-2022  ANTHONY WAYNE ELEMENTARY  Burtrum ELA and SS 2021-2022
# 233    2021-2022  ANTHONY WAYNE ELEMENTARY  Burtrum ELA and SS 2021-2022
# 234    2021-2022  ANTHONY WAYNE ELEMENTARY  Burtrum ELA and SS 2021-2022
# 235    2021-2022  ANTHONY WAYNE ELEMENTARY  Burtrum ELA and SS 2021-2022
# 236    2021-2022  ANTHONY WAYNE ELEMENTARY  Burtrum ELA and SS 2021-2022
# ...          ...                       ...                           ...
# 1774   2021-2022     WM SCHENCK ELEMENTARY               Shelton Writing
# 1775   2021-2022     WM SCHENCK ELEMENTARY               Shelton Writing
# 1776   2021-2022     WM SCHENCK ELEMENTARY               Shelton Writing
# 1777   2021-2022     WM SCHENCK ELEMENTARY               Shelton Writing
# 1778   2021-2022     WM SCHENCK ELEMENTARY               Shelton Writing
#
#                        Lesson Type Class Subject Teacher Name [Sensitive]  \
# ...

# %%
bchmrk2122_ws.groupby(['Enrolled Grade', 'Lesson Type'])['Writing Score'].mean()
# Out:
# Enrolled Grade  Lesson Type
# 4               Benchmark - Baseline Writing    28.591549
# 5               Benchmark - Baseline Writing    47.411765
# 6               Benchmark - Baseline Writing    46.215054
#                 Benchmark - Mid-Year            57.479730
# 7               Benchmark - Baseline Writing    42.791667
#                 Benchmark - Mid-Year            46.479290
# 8               Benchmark - Baseline Writing    52.104972
#                 Benchmark - Mid-Year            54.119318
# 9               Benchmark - Baseline Writing    56.630769
#                 Benchmark - Mid-Year            59.521368
# 10              Benchmark - Baseline Writing    58.081967
#                 Benchmark - Mid-Year            57.204918
# 11              Benchmark - Mid-Year            83.000000
# Name: Writing Score, dtype: float64

# %%
bchmrk2122_wc.groupby(['Enrolled Grade', 'Lesson Type'])['Word Count'].mean()
# Out:
# Enrolled Grade  Lesson Type
# 4               Benchmark - Baseline Writing     55.873239
# 5               Benchmark - Baseline Writing    119.588235
# 6               Benchmark - Baseline Writing    136.956989
#                 Benchmark - Mid-Year            229.500000
# 7               Benchmark - Baseline Writing    195.803571
#                 Benchmark - Mid-Year            304.654762
# 8               Benchmark - Baseline Writing    300.338889
#                 Benchmark - Mid-Year            367.115607
# 9               Benchmark - Baseline Writing    372.834646
#                 Benchmark - Mid-Year            386.646552
# 10              Benchmark - Baseline Writing    366.067797
#                 Benchmark - Mid-Year            291.590164
# 11              Benchmark - Mid-Year            402.000000
# Name: Word Count, dtype: float64

# %% [markdown]
# ## T-test

# %%
# reshape the dataset so that BOY and MOY can be two columns side by side 

pivotgroup_bchmrk2122 = ['School Name', 'Full Name', 'Enrolled Grade', 'Lesson Type']

bchmrk2122_ws_p = drop_columns(bchmrk2122_ws, pivotgroup_bchmrk2122, 'Writing Score')

bchmrk2122_ws_p = bchmrk2122_ws_p.pivot(index=['School Name', 'Full Name','Enrolled Grade'], columns='Lesson Type', values='Writing Score')
bchmrk2122_ws_p = bchmrk2122_ws_p.reset_index()

bchmrk2122_ws_p = bchmrk2122_ws_p.dropna()

print(bchmrk2122_ws_p[['Benchmark - Baseline Writing','Benchmark - Mid-Year']].describe())
print(ttest_rel(bchmrk2122_ws_p['Benchmark - Baseline Writing'], bchmrk2122_ws_p['Benchmark - Mid-Year']))

# bchmrk2122_ws_p: 419 rows × 4 columns
## t-test results have shown that there is a difference between boy and moy, and the writing scores improve
# Out:
# Lesson Type  Benchmark - Baseline Writing  Benchmark - Mid-Year
# count                          568.000000            568.000000
# mean                            50.647887             54.630282
# std                             17.034438             15.857187
# min                             18.000000              3.000000
# 25%                             37.000000             44.000000
# 50%                             51.000000             55.000000
# 75%                             63.000000             65.000000
# max                             95.000000             95.000000
# Ttest_relResult(statistic=-6.21792805472968, pvalue=9.77791210405921e-10)

# %%
bchmrk2122_ws_p
# Out:
# Lesson Type               School Name               Full Name  Enrolled Grade  \
# 0            ANTHONY WAYNE ELEMENTARY           Adriaen Beane               6
# 2            ANTHONY WAYNE ELEMENTARY  Annabelle Wolfinbarger               6
# 4            ANTHONY WAYNE ELEMENTARY            Ava Milligan               6
# 8            ANTHONY WAYNE ELEMENTARY         Bryan Smithwick               6
# 9            ANTHONY WAYNE ELEMENTARY          Cadence Setser               6
# ..                                ...                     ...             ...
# 971             WM SCHENCK ELEMENTARY          Nathyn Watkins               6
# 973             WM SCHENCK ELEMENTARY          Patricia Alton               6
# 975             WM SCHENCK ELEMENTARY         Tristan Hensley               6
# 976             WM SCHENCK ELEMENTARY            Triston Belt               6
# 977             WM SCHENCK ELEMENTARY            Zaydin Azeez               6
#
# ...

# %%
# repeat for word count
bchmrk2122_wc_p = drop_columns(bchmrk2122_wc, pivotgroup_bchmrk2122, 'Word Count')

bchmrk2122_wc_p = bchmrk2122_wc_p.pivot(index=['School Name','Full Name','Enrolled Grade'], columns='Lesson Type', values='Word Count')
bchmrk2122_wc_p = bchmrk2122_wc_p.reset_index()

bchmrk2122_wc_p = bchmrk2122_wc_p.dropna()

print(bchmrk2122_wc_p[['Benchmark - Baseline Writing','Benchmark - Mid-Year']].describe())
print(ttest_rel(bchmrk2122_wc_p['Benchmark - Baseline Writing'], bchmrk2122_wc_p['Benchmark - Mid-Year']))
## t-test results have shown that there is a difference between boy and moy, and the writing scores improve
# Out:
# Lesson Type  Benchmark - Baseline Writing  Benchmark - Mid-Year
# count                          561.000000            561.000000
# mean                           254.314617            325.723708
# std                            174.999397            156.768837
# min                              5.000000              5.000000
# 25%                            105.000000            214.000000
# 50%                            229.000000            322.000000
# 75%                            388.000000            429.000000
# max                            804.000000            814.000000
# Ttest_relResult(statistic=-11.72088917979407, pvalue=1.5799883230441861e-28)

# %%
bchmrk2122_wc_p
# Out:
#                   School Name        Full Name  Enrolled Grade  \
# 0    ANTHONY WAYNE ELEMENTARY    Adriaen Beane               6
# 1    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 2    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 3    ANTHONY WAYNE ELEMENTARY  Bryan Smithwick               6
# 4    ANTHONY WAYNE ELEMENTARY   Cadence Setser               6
# ..                        ...              ...             ...
# 471     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 472     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 473     WM SCHENCK ELEMENTARY     Triston Belt               6
# 474     WM SCHENCK ELEMENTARY     Triston Belt               6
# 475     WM SCHENCK ELEMENTARY     Zaydin Azeez               6
#
#      Benchmark - Baseline Writing  Benchmark - Mid-Year School Year  \
# 0                            38.0                 138.0   2021-2022
# 1                           277.0                 299.0         NaN
# ...

# %%
bchmrk2122_wc_p.groupby(['School Year','Enrolled Grade'])['Benchmark - Baseline Writing','Benchmark - Mid-Year'].mean()
# Out:
#                             Benchmark - Baseline Writing  Benchmark - Mid-Year
# School Year Enrolled Grade
# 2021-2022   6                                 132.741667            222.858333
#             7                                 161.292308            277.046154
#             8                                 309.953488            378.666667
#             9                                 406.135593            419.576271
#             10                                420.442857            366.114286

# %% [markdown]
# ## Boxplots (just for viewing the structure)

# %%
# boxplot: writing scores by boy and eoy (for each grade)
plt.figure(figsize = (10,8))

for n in range(4,12): 
    plt.figure(figsize = (10,8))
    # choose the grade  
    grade = bchmrk2122_ws[bchmrk2122_ws['Enrolled Grade']==n] 
    
    ax = sns.boxplot(x=grade['Lesson Type'],y=grade['Writing Score'])
    ax.set_title('Grade %d' %n)
#     plt.savefig('/Users/spencersu/Desktop/JCPS Efficacy Report/Datasets/boxplot grade' + str(n) +'.png')
    plt.show()

# %%
# writing score general boxplot
plt.figure(figsize = (10,8))
ax = sns.boxplot(x=bchmrk2122_ws['Lesson Type'],y=bchmrk2122_ws['Writing Score'])
# ax.set_title('Grade %d' %n)
# plt.savefig('/Users/spencersu/Desktop/JCPS Efficacy Report/Datasets/boxplot grade' + str(n) +'.png')
plt.show()

# %%
# bchmrk2122_ws.to_csv(os.path.join(path, 'Benchmark Scores for Graphs.csv'))

# %%
# boxplot: word count by boy and eoy (for each grade)
plt.figure(figsize = (10,8))

for n in range(4,12): 
    plt.figure(figsize = (10,8))
    # choose the grade  
    grade = bchmrk2122_wc[bchmrk2122_wc['Enrolled Grade']==n] 
    
    ax = sns.boxplot(x=grade['Lesson Type'],y=grade['Word Count'])
    ax.set_title('Grade %d' %n)
#     plt.savefig('/Users/spencersu/Desktop/JCPS Efficacy Report/Datasets/boxplot grade' + str(n) +'.png')
    plt.show()

# %%
# word count general boxplot
plt.figure(figsize = (10,8))
ax = sns.boxplot(x=bchmrk2122_wc['Lesson Type'],y=bchmrk2122_wc['Word Count'])
# ax.set_title('Grade %d' %n)
# plt.savefig('/Users/spencersu/Desktop/JCPS Efficacy Report/Datasets/boxplot grade' + str(n) +'.png')
plt.show()

# %% [markdown]
# ## Scatterplot (usage vs. word count)

# %%
bchmrk2122_ws_p['score_improvement'] = bchmrk2122_ws_p['Benchmark - Mid-Year'] - bchmrk2122_ws_p['Benchmark - Baseline Writing']
## count the number of writing lessons a student submit 

num_wrtlsn = wrtlsn.groupby(['School Year','School Name','Full Name','Enrolled Grade'])['Student Assignment ID'].count()
num_wrtlsn = num_wrtlsn.reset_index()
num_wrtlsn.rename(columns={'Student Assignment ID': 'num_asgmt'}, inplace = True)

bchmrk2122_ws_p = pd.merge(bchmrk2122_ws_p,num_wrtlsn,on=['School Name','Full Name','Enrolled Grade'], how='inner')

# 418 rows × 7 columns

# %%
num_wrtlsn['School Year'] = num_wrtlsn[num_wrtlsn['School Year'] == '2021-2022']

# %%
num_wrtlsn
# Out:
#      School Year               School Name             Full Name  \
# 0            NaN  ANTHONY WAYNE ELEMENTARY       Abigail Plowman
# 1            NaN  ANTHONY WAYNE ELEMENTARY         Alyssa Mercer
# 2            NaN  ANTHONY WAYNE ELEMENTARY          Andrew Cooke
# 3            NaN  ANTHONY WAYNE ELEMENTARY         Ashlee Deaton
# 4            NaN  ANTHONY WAYNE ELEMENTARY  Brandon Bastin-Knott
# ...          ...                       ...                   ...
# 3198   2021-2022     WM SCHENCK ELEMENTARY        Patricia Alton
# 3199   2021-2022     WM SCHENCK ELEMENTARY         Timothy Tinch
# 3200   2021-2022     WM SCHENCK ELEMENTARY       Tristan Hensley
# 3201   2021-2022     WM SCHENCK ELEMENTARY          Triston Belt
# 3202   2021-2022     WM SCHENCK ELEMENTARY          Zaydin Azeez
#
#       Enrolled Grade  num_asgmt
# 0                  8          3
# 1                  8          3
# 2                  8          3
# 3                  8          3
# ...

# %%
bchmrk2122_ws_p
# Out:
#                   School Name        Full Name  Enrolled Grade  \
# 0    ANTHONY WAYNE ELEMENTARY    Adriaen Beane               6
# 1    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 2    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 3    ANTHONY WAYNE ELEMENTARY  Bryan Smithwick               6
# 4    ANTHONY WAYNE ELEMENTARY   Cadence Setser               6
# ..                        ...              ...             ...
# 477     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 478     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 479     WM SCHENCK ELEMENTARY     Triston Belt               6
# 480     WM SCHENCK ELEMENTARY     Triston Belt               6
# 481     WM SCHENCK ELEMENTARY     Zaydin Azeez               6
#
#      Benchmark - Baseline Writing  Benchmark - Mid-Year  score_improvement  \
# 0                            29.0                  60.0               31.0
# ...

# %%
for n in range (1,4):
    sns.set_style(style='white')
    plt.figure(figsize = (10,8))
    sns.regplot(bchmrk2122_ws_p['num_asgmt'],bchmrk2122_ws_p['Benchmark - Mid-Year'], order = n,
                scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
                line_kws={"color": "#ff6800"}, ci=None)
    plt.xlabel('The Number of Assignments')
    plt.ylabel('Writing Score')
    plt.title("Number of Assignments vs. MOY Writing Score", fontsize=15)
    plt.savefig(os.path.join(path,'The Number of Assignments vs. MOY Writing Score (Order ' + str(n) +').png'))
    plt.show()

# %%
for n in range (1,4):
    sns.set_style(style='white')
    plt.figure(figsize = (10,8))
    sns.regplot(bchmrk2122_ws_p['num_asgmt'],bchmrk2122_ws_p['score_improvement'], order = n,
                scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
                line_kws={"color": "#ff6800"}, ci=None)
    plt.xlabel('The Number of Assignments')
    plt.ylabel('Writing Score Growth')
    plt.title("Number of Assignments vs. Writing Score Growth", fontsize=15)
    plt.savefig(os.path.join(path,'The Number of Assignments vs. Writing Score Growth (Order ' + str(n) +').png'))
    plt.show()

# %%
# merge the number of writing lessons a student submit into 

bchmrk2122_wc_p = pd.merge(bchmrk2122_wc_p,num_wrtlsn,on=['School Name','Full Name','Enrolled Grade'], how='inner')

# 414 rows × 7 columns

bchmrk2122_wc_p['wordcount_improvement'] = bchmrk2122_wc_p['Benchmark - Mid-Year'] - bchmrk2122_wc_p['Benchmark - Baseline Writing']

# %%
bchmrk2122_wc_p
# Out:
#                   School Name        Full Name  Enrolled Grade  \
# 0    ANTHONY WAYNE ELEMENTARY    Adriaen Beane               6
# 1    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 2    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 3    ANTHONY WAYNE ELEMENTARY  Bryan Smithwick               6
# 4    ANTHONY WAYNE ELEMENTARY   Cadence Setser               6
# ..                        ...              ...             ...
# 471     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 472     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 473     WM SCHENCK ELEMENTARY     Triston Belt               6
# 474     WM SCHENCK ELEMENTARY     Triston Belt               6
# 475     WM SCHENCK ELEMENTARY     Zaydin Azeez               6
#
#      Benchmark - Baseline Writing  Benchmark - Mid-Year School Year  \
# 0                            38.0                 138.0   2021-2022
# 1                           277.0                 299.0         NaN
# ...

# %%
for n in range (1,4):
    sns.set_style(style='white')
    plt.figure(figsize = (10,8))
    sns.regplot(bchmrk2122_wc_p['num_asgmt'],bchmrk2122_wc_p['wordcount_improvement'], order = n,
                scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
                line_kws={"color": "#ff6800"}, ci=None)
    plt.xlabel('The Number of Assignments')
    plt.ylabel('Word Count Difference')
    plt.title("Number of Assignments vs. Word Count", fontsize=15)
    plt.savefig(os.path.join(path,'The Number of Assignments vs. Word Count Improvement (Order ' + str(n) +').png'))
    plt.show()

# %%
for n in range (1,4):
    sns.set_style(style='white')
    plt.figure(figsize = (10,8))
    sns.regplot(bchmrk2122_wc_p['num_asgmt'],bchmrk2122_wc_p['Benchmark - Mid-Year'], order = n,
                scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
                line_kws={"color": "#ff6800"}, ci=None)
    plt.xlabel('The Number of Assignments')
    plt.ylabel('Word Count')
    plt.title("The Number of Assignments vs. MOY Word Count", fontsize=15)
    plt.savefig(os.path.join(path,'The Number of Assignments vs. MOY Word Count (Order ' + str(n) +').png'))
    plt.show()

# %% [markdown]
# ## Regression (Usage vs. Scores)

# %%
bchmrk2122_ws_p
# Out:
#                   School Name        Full Name  Enrolled Grade  \
# 0    ANTHONY WAYNE ELEMENTARY    Adriaen Beane               6
# 1    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 2    ANTHONY WAYNE ELEMENTARY     Ava Milligan               6
# 3    ANTHONY WAYNE ELEMENTARY  Bryan Smithwick               6
# 4    ANTHONY WAYNE ELEMENTARY   Cadence Setser               6
# ..                        ...              ...             ...
# 477     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 478     WM SCHENCK ELEMENTARY  Tristan Hensley               6
# 479     WM SCHENCK ELEMENTARY     Triston Belt               6
# 480     WM SCHENCK ELEMENTARY     Triston Belt               6
# 481     WM SCHENCK ELEMENTARY     Zaydin Azeez               6
#
#      Benchmark - Baseline Writing  Benchmark - Mid-Year  score_improvement  \
# 0                            29.0                  60.0               31.0
# ...

# %%
df_reg = bchmrk2122_ws_p.rename(columns={bchmrk2122_ws_p.columns[0]: 'school_name', 
                                         bchmrk2122_ws_p.columns[1]: 'student_name',
                                         bchmrk2122_ws_p.columns[2]: 'enrolled_grade',
                                         bchmrk2122_ws_p.columns[3]: 'BOY_score',
                                         bchmrk2122_ws_p.columns[4]: 'MOY_score'}, inplace = False)

# %%
results = smf.ols('MOY_score ~ num_asgmt + C(enrolled_grade) + C(school_name)', data=df_reg).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              MOY_score   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     6.901
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):           1.32e-08
# Time:                        10:56:03   Log-Likelihood:                -2011.5
# No. Observations:                 482   AIC:                             4041.
# Df Residuals:                     473   BIC:                             4079.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
results2 = smf.ols('MOY_score ~ num_asgmt^2 + C(enrolled_grade) + C(school_name)', data=df_reg).fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              MOY_score   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     7.733
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):           9.14e-10
# Time:                        10:56:03   Log-Likelihood:                -2008.5
# No. Observations:                 482   AIC:                             4035.
# Df Residuals:                     473   BIC:                             4073.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Case study

# %%
subset_ws = bchmrk2122_ws_p[bchmrk2122_ws_p['num_asgmt']>=3]

# %%
subset_ws
# Out:
#               School Name        Full Name  Enrolled Grade  \
# 40   FRANKLIN HIGH SCHOOL    Alexia Azbill              10
# 43   FRANKLIN HIGH SCHOOL    Alexis Dearth              10
# 47   FRANKLIN HIGH SCHOOL    Aliysa Mullin              10
# 53   FRANKLIN HIGH SCHOOL     Austin Hitte              10
# 57   FRANKLIN HIGH SCHOOL      Ava Baumann              10
# ..                    ...              ...             ...
# 417     HUNTER ELEMENTARY  Reagan Pieschel               6
# 419     HUNTER ELEMENTARY    Samuel Tsitey               6
# 420     HUNTER ELEMENTARY    Tripp Mallion               6
# 421     HUNTER ELEMENTARY    Xavier Duarte               6
# 422     HUNTER ELEMENTARY  Zachary Quillen               6
#
#      Benchmark - Baseline Writing  Benchmark - Mid-Year  score_improvement  \
# 40                           47.0                  59.0               12.0
# 43                           48.0                  46.0               -2.0
# ...

# %%
# why three? can we add a step to suggest three makes a significant difference in other district? 
sns.set_style(style='white')
plt.figure(figsize = (10,8))
sns.regplot(subset_ws['num_asgmt'],subset_ws['Benchmark - Mid-Year'], order = 1,
            scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
            line_kws={"color": "#ff6800"}, ci=None)
plt.xlabel('The Number of Assignments')
plt.ylabel('Word Count')
plt.title("The Number of Assignments vs. MOY Score", fontsize=15)
plt.savefig(os.path.join(path,'The Number of Assignments vs. MOY.png'))
plt.show()

# %%
df_reg2 = subset_ws.rename(columns={subset_ws.columns[0]: 'school_name', 
                                    subset_ws.columns[1]: 'student_name',
                                    subset_ws.columns[2]: 'enrolled_grade',
                                    subset_ws.columns[3]: 'BOY_score',
                                    subset_ws.columns[4]: 'MOY_score'}, inplace = False)

# %%
df_reg2
# Out:
#               school_name     student_name  enrolled_grade  BOY_score  \
# 40   FRANKLIN HIGH SCHOOL    Alexia Azbill              10       47.0
# 43   FRANKLIN HIGH SCHOOL    Alexis Dearth              10       48.0
# 47   FRANKLIN HIGH SCHOOL    Aliysa Mullin              10       66.0
# 53   FRANKLIN HIGH SCHOOL     Austin Hitte              10       57.0
# 57   FRANKLIN HIGH SCHOOL      Ava Baumann              10       62.0
# ..                    ...              ...             ...        ...
# 417     HUNTER ELEMENTARY  Reagan Pieschel               6       60.0
# 419     HUNTER ELEMENTARY    Samuel Tsitey               6       34.0
# 420     HUNTER ELEMENTARY    Tripp Mallion               6       61.0
# 421     HUNTER ELEMENTARY    Xavier Duarte               6       54.0
# 422     HUNTER ELEMENTARY  Zachary Quillen               6       45.0
#
#      MOY_score  score_improvement School Year  num_asgmt
# 40        59.0               12.0   2020-2021          6
# ...

# %%
results3 = smf.ols('MOY_score ~ num_asgmt + C(enrolled_grade) + C(school_name)', data=df_reg2).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              MOY_score   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     6.171
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):           3.99e-05
# Time:                        11:01:58   Log-Likelihood:                -525.21
# No. Observations:                 126   AIC:                             1062.
# Df Residuals:                     120   BIC:                             1079.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
subset_wc = bchmrk2122_wc_p[bchmrk2122_wc_p['num_asgmt']>=3]

# %%
sns.set_style(style='white')
plt.figure(figsize = (10,8))
sns.regplot(subset_wc['num_asgmt'],subset_wc['Benchmark - Mid-Year'], order = 1,
            scatter_kws={"color": "#2f7fe2",'s':8}, truncate = False, x_jitter=.1,marker='o',
            line_kws={"color": "#ff6800"}, ci=None)
plt.xlabel('The Number of Assignments')
plt.ylabel('Word Count')
plt.title("The Number of Assignments vs. MOY Word Count", fontsize=15)
plt.savefig(os.path.join(path,'The Number of Assignments vs. MOY Word Count.png'))
plt.show()

# %%
df_reg3 = subset_wc.rename(columns={subset_wc.columns[0]: 'school_name', 
                                    subset_wc.columns[1]: 'student_name',
                                    subset_wc.columns[2]: 'enrolled_grade',
                                    subset_wc.columns[3]: 'BOY_word',
                                    subset_wc.columns[4]: 'MOY_word'}, inplace = False)

# %%
results4 = smf.ols('MOY_word ~ num_asgmt + C(enrolled_grade) + C(school_name)', data=df_reg3).fit()
print(results4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               MOY_word   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     3.987
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):            0.00222
# Time:                        11:32:17   Log-Likelihood:                -777.97
# No. Observations:                 125   AIC:                             1568.
# Df Residuals:                     119   BIC:                             1585.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...
